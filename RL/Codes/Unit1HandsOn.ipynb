# %%
# Install Gymnasium with the LunarLander-v2 environment
# !pip install gymnasium[box2d]

# Install Stable-Baselines3 with extra dependencies
# !pip install stable-baselines3[extra]

# Install the Hugging Face library for Stable-Baselines3 integration
# !pip install huggingface_sb3
# Out:
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame==2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.1.3)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.3.0)
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.10/dist-packages (2.0.0a5)
# Requirement already satisfied: gymnasium==0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (0.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.8.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.17.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: shimmy~=0.2.1 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=0.2.1; extra == "extra"->stable-baselines3[extra]) (0.2.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (11.0.0)
# Requirement already satisfied: autorom~=0.6.0 in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.0->autorom[accept-rom-license]~=0.6.0; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.0->autorom[accept-rom-license]~=0.6.0; extra == "extra"->stable-baselines3[extra]) (2.32.3)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: ale-py~=0.8.1 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=0.2.1; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1; extra == "extra"->stable-baselines3[extra]) (6.4.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.0->autorom[accept-rom-license]~=0.6.0; extra == "extra"->stable-baselines3[extra]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.0->autorom[accept-rom-license]~=0.6.0; extra == "extra"->stable-baselines3[extra]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.0->autorom[accept-rom-license]~=0.6.0; extra == "extra"->stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.0->autorom[accept-rom-license]~=0.6.0; extra == "extra"->stable-baselines3[extra]) (2024.12.14)
# Requirement already satisfied: huggingface_sb3 in /usr/local/lib/python3.10/dist-packages (3.0)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (0.27.0)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (6.0.2)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2024.12.14)

# %%
pip install pyvirtualdisplay
# Out:
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
import os

os.kill(os.getpid(), 9)

# %%
# !apt-get install -y xvfb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 49 not upgraded.
# Need to get 7,815 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.12 [864 kB]
# Fetched 7,815 kB in 1s (7,383 kB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 123632 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link

# %%
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import (
    notebook_login,
)  # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/util.py:55: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs; see https://jax.readthedocs.io/en/latest/aot.html. For example, replace xla_computation(f)(*xs) with jit(f).lower(*xs).compiler_ir('hlo'). See CHANGELOG.md for 0.4.30 for more examples.
#   from jax import xla_computation as _xla_computation

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
    # Take a random action
    action = env.action_space.sample()
    print("Action taken:", action)

    # Do this action in the environment and get
    # next_state, reward, terminated, truncated and info
    observation, reward, terminated, truncated, info = env.step(action)

    # If the game is terminated (in our case we land, crashed) or truncated (timeout)
    if terminated or truncated:
        # Reset the environment
        print("Environment is reset")
        observation, info = env.reset()

env.close()
# Out:
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type SwigPyPacked has no __module__ attribute
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type SwigPyObject has no __module__ attribute
# <frozen importlib._bootstrap>:241: DeprecationWarning: builtin type swigvarlink has no __module__ attribute
# /usr/local/lib/python3.10/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# Action taken: 3
# Action taken: 1
# Action taken: 3
# Action taken: 1
# Action taken: 1
# Action taken: 2
# Action taken: 2
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 0
# Action taken: 3
# Action taken: 0
# Action taken: 0
# Action taken: 2
# Action taken: 3
# Action taken: 2
# Action taken: 3
# Action taken: 3
# Action taken: 3

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample())  # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-14.890792  -85.59688    -3.1926484   1.063874    3.0779445  -3.746077
#    0.7209993   0.4220029]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample())  # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 3

# %%
# Create the environment
env = make_vec_env("LunarLander-v2", n_envs=16)

# %%
# Create environment
env = gym.make('LunarLander-v2')

# Instantiate the agent
model = PPO('MlpPolicy', env, verbose=1)
# Train the agent
model.learn(total_timesteps=int(2e5))

model = PPO(
    policy="MlpPolicy",
    env=env,
    n_steps=1024,
    batch_size=64,
    n_epochs=4,
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.01,
    verbose=1,
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.6     |
# |    ep_rew_mean     | -205     |
# | time/              |          |
# |    fps             | 661      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.7         |
# |    ep_rew_mean          | -204         |
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0033420476 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00346      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 1.98e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.6         |
# |    ep_rew_mean          | -189         |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 3            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0037520966 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.013       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 657          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00552     |
# |    value_loss           | 1.87e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.8         |
# |    ep_rew_mean          | -193         |
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 4            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0076746307 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00771     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 333          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00723     |
# |    value_loss           | 827          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.3       |
# |    ep_rew_mean          | -198       |
# | time/                   |            |
# |    fps                  | 480        |
# |    iterations           | 5          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00717537 |
# |    clip_fraction        | 0.0299     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.0032    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.02e+03   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 1.27e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -199        |
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 6           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011372317 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.000678   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 496         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0069     |
# |    value_loss           | 1.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -209        |
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 7           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008066949 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.00144     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 354         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0044     |
# |    value_loss           | 1.05e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -217        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 8           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008094434 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.000443   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 446         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 1.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -215        |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 9           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008005928 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00116    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 528         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00505    |
# |    value_loss           | 781         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -215        |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 10          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008191094 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.014      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 237         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00783    |
# |    value_loss           | 656         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -221         |
# | time/                   |              |
# |    fps                  | 472          |
# |    iterations           | 11           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0135555435 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.000489    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 192          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00657     |
# |    value_loss           | 640          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -216         |
# | time/                   |              |
# |    fps                  | 474          |
# |    iterations           | 12           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0066679935 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.00247     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 419          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 1.06e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -198        |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 13          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010714391 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -1.91e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 477         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00784    |
# |    value_loss           | 673         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -193        |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 14          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014843448 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 4.07e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 326         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 573         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | -185        |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 15          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006270771 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.000284   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 170         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00749    |
# |    value_loss           | 343         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 120          |
# |    ep_rew_mean          | -188         |
# | time/                   |              |
# |    fps                  | 469          |
# |    iterations           | 16           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0043776603 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.00574      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 393          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 510          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 124        |
# |    ep_rew_mean          | -177       |
# | time/                   |            |
# |    fps                  | 471        |
# |    iterations           | 17         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00864728 |
# |    clip_fraction        | 0.0437     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.0498     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 239        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0062    |
# |    value_loss           | 402        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | -178         |
# | time/                   |              |
# |    fps                  | 472          |
# |    iterations           | 18           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0060022348 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.0307       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 212          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00578     |
# |    value_loss           | 729          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | -192        |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 19          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009916134 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 104         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 425         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -202        |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 20          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004025109 |
# |    clip_fraction        | 0.00303     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 236         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 675         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | -212         |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 21           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0050047673 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.323        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 173          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00446     |
# |    value_loss           | 581          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 167         |
# |    ep_rew_mean          | -216        |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 22          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006836667 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0083     |
# |    value_loss           | 339         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | -218        |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 23          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007021439 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00728    |
# |    value_loss           | 254         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 192          |
# |    ep_rew_mean          | -208         |
# | time/                   |              |
# |    fps                  | 470          |
# |    iterations           | 24           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0065578604 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.369        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.9         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00501     |
# |    value_loss           | 256          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -197        |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 25          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008552277 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.4        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 153         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 208         |
# |    ep_rew_mean          | -192        |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 26          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004431869 |
# |    clip_fraction        | 0.0248      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 293         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 223         |
# |    ep_rew_mean          | -190        |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 27          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007318952 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 113         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 205         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 28          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.007412626 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.3        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 151         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 253          |
# |    ep_rew_mean          | -176         |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 29           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0061723087 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.56         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00471     |
# |    value_loss           | 192          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 265        |
# |    ep_rew_mean          | -171       |
# | time/                   |            |
# |    fps                  | 467        |
# |    iterations           | 30         |
# |    time_elapsed         | 131        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00537915 |
# |    clip_fraction        | 0.0592     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.582      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.9       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00643   |
# |    value_loss           | 78         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 31          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010699718 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.4        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00827    |
# |    value_loss           | 134         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 283         |
# |    ep_rew_mean          | -158        |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 32          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009552637 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 120         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00843    |
# |    value_loss           | 258         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | -148        |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 33          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007345095 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 246         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 309         |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 34          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008907685 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 68.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 35          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006406617 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00788    |
# |    value_loss           | 376         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 36           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0058614314 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.997       |
# |    explained_variance   | 0.175        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.5         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 164          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 338          |
# |    ep_rew_mean          | -84.6        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 37           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0051425667 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.96        |
# |    explained_variance   | 0.0754       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.3         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00481     |
# |    value_loss           | 267          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 350          |
# |    ep_rew_mean          | -81          |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 38           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0135040935 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00924     |
# |    value_loss           | 233          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 359         |
# |    ep_rew_mean          | -78.6       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 39          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.022579521 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35          |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 99          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 374         |
# |    ep_rew_mean          | -77.2       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 40          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008766615 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00706    |
# |    value_loss           | 171         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | -71.6       |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 41          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008303871 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 98.4        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.007      |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | -73.7       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 42          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.010915833 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.5        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 96.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 408          |
# |    ep_rew_mean          | -76.8        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 43           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0056955935 |
# |    clip_fraction        | 0.09         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.991       |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00576     |
# |    value_loss           | 102          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 413         |
# |    ep_rew_mean          | -81.1       |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 44          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013382943 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 66.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 428          |
# |    ep_rew_mean          | -80          |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 45           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0050017564 |
# |    clip_fraction        | 0.0958       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.482        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.5         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00737     |
# |    value_loss           | 46           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 449         |
# |    ep_rew_mean          | -76.6       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 46          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008998673 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.84        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 18.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 464          |
# |    ep_rew_mean          | -76.8        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 47           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0024809137 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.357        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.9         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 78.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 479         |
# |    ep_rew_mean          | -77.3       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 48          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007882609 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.24        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00524    |
# |    value_loss           | 49.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 492         |
# |    ep_rew_mean          | -73.6       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 49          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008384273 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.11        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 26.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 507        |
# |    ep_rew_mean          | -69.2      |
# | time/                   |            |
# |    fps                  | 467        |
# |    iterations           | 50         |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.00959731 |
# |    clip_fraction        | 0.0958     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.293      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.3       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00751   |
# |    value_loss           | 57.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 528        |
# |    ep_rew_mean          | -60.4      |
# | time/                   |            |
# |    fps                  | 467        |
# |    iterations           | 51         |
# |    time_elapsed         | 223        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.00254481 |
# |    clip_fraction        | 0.0167     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.916     |
# |    explained_variance   | 0.319      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 20.2       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.00296   |
# |    value_loss           | 101        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 543          |
# |    ep_rew_mean          | -59.7        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 52           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0038306518 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.94        |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 109          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 116          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 560         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 53          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.006290032 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00339    |
# |    value_loss           | 21.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 568         |
# |    ep_rew_mean          | -56.9       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 54          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.007303254 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 9.99        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 576         |
# |    ep_rew_mean          | -57.9       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 55          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.006023229 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# ...
# |    ep_len_mean          | 826          |
# |    ep_rew_mean          | 3.63         |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 81           |
# |    time_elapsed         | 355          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0017878844 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.885       |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.3         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 107          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 823        |
# |    ep_rew_mean          | 14.2       |
# | time/                   |            |
# |    fps                  | 467        |
# |    iterations           | 82         |
# |    time_elapsed         | 359        |
# |    total_timesteps      | 167936     |
# | train/                  |            |
# |    approx_kl            | 0.00415931 |
# |    clip_fraction        | 0.0455     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.863     |
# |    explained_variance   | 0.577      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.3       |
# |    n_updates            | 810        |
# |    policy_gradient_loss | -0.00177   |
# |    value_loss           | 122        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 824          |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 83           |
# |    time_elapsed         | 364          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0050784172 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.791       |
# |    explained_variance   | 0.603        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 163          |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00383     |
# |    value_loss           | 177          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 826         |
# |    ep_rew_mean          | 26.4        |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 84          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.042602308 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.728      |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 108         |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00902    |
# |    value_loss           | 76.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 826         |
# |    ep_rew_mean          | 29          |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 85          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.012802212 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 59.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 816         |
# |    ep_rew_mean          | 34.1        |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 86          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.013422759 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.953      |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.46        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 72.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 818          |
# |    ep_rew_mean          | 37.1         |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 87           |
# |    time_elapsed         | 381          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0026997244 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.717       |
# |    explained_variance   | 0.473        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.6         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.000494    |
# |    value_loss           | 168          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 806         |
# |    ep_rew_mean          | 38.2        |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 88          |
# |    time_elapsed         | 386         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.015018034 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.459       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 4.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 786         |
# |    ep_rew_mean          | 34.3        |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 89          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.006792363 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.825      |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.1        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 118         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 778          |
# |    ep_rew_mean          | 29           |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 90           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0039743893 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.853       |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.1         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 136          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 752         |
# |    ep_rew_mean          | 26.7        |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 91          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.004144841 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.1        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00388    |
# |    value_loss           | 59.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 734          |
# |    ep_rew_mean          | 25.3         |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 92           |
# |    time_elapsed         | 403          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0021754191 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.3         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 112          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 731          |
# |    ep_rew_mean          | 22.4         |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 93           |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0033323888 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.797       |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.53         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 106          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 722         |
# |    ep_rew_mean          | 16          |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 94          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.005970718 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 25.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 708         |
# |    ep_rew_mean          | 11.9        |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 95          |
# |    time_elapsed         | 416         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.008896747 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 38.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 708        |
# |    ep_rew_mean          | 12.5       |
# | time/                   |            |
# |    fps                  | 467        |
# |    iterations           | 96         |
# |    time_elapsed         | 420        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.00959927 |
# |    clip_fraction        | 0.0723     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.908     |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.3       |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.00378   |
# |    value_loss           | 41.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 711          |
# |    ep_rew_mean          | 15.4         |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 97           |
# |    time_elapsed         | 425          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0077095563 |
# |    clip_fraction        | 0.0808       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.79         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 11.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 711         |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 98          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.009375173 |
# |    clip_fraction        | 0.0994      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.886       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 12          |
# -----------------------------------------
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model_name = "ppo-LunarLander-v2"
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    value_loss           | 355           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 561         |
# |    ep_rew_mean          | 23.9        |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 131         |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 134144      |
# | train/                  |             |
# |    approx_kl            | 0.001160241 |
# |    clip_fraction        | 0.000244    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 192         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 569          |
# |    ep_rew_mean          | 25.5         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 132          |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 135168       |
# | train/                  |              |
# |    approx_kl            | 0.0071455436 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.917       |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.8         |
# |    n_updates            | 524          |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 148          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 576         |
# |    ep_rew_mean          | 27.2        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 133         |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 136192      |
# | train/                  |             |
# |    approx_kl            | 0.013094422 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34          |
# |    n_updates            | 528         |
# |    policy_gradient_loss | -0.00536    |
# |    value_loss           | 68.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 584         |
# |    ep_rew_mean          | 28.8        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 134         |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 137216      |
# | train/                  |             |
# |    approx_kl            | 0.013105238 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.1        |
# |    n_updates            | 532         |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 64.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 593          |
# |    ep_rew_mean          | 29.5         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 135          |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 138240       |
# | train/                  |              |
# |    approx_kl            | 0.0036860134 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.34         |
# |    n_updates            | 536          |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 24.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 594         |
# |    ep_rew_mean          | 29.4        |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 136         |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.008191958 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.52        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 23.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 595         |
# |    ep_rew_mean          | 29.4        |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 137         |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 140288      |
# | train/                  |             |
# |    approx_kl            | 0.004774361 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 148         |
# |    n_updates            | 544         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 230         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | 31.1         |
# | time/                   |              |
# |    fps                  | 571          |
# |    iterations           | 138          |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 141312       |
# | train/                  |              |
# |    approx_kl            | 0.0021783262 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.896        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 104          |
# |    n_updates            | 548          |
# |    policy_gradient_loss | -0.00258     |
# |    value_loss           | 183          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 610         |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 139         |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 142336      |
# | train/                  |             |
# |    approx_kl            | 0.016836476 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.06        |
# |    n_updates            | 552         |
# |    policy_gradient_loss | -0.00478    |
# |    value_loss           | 33          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 618          |
# |    ep_rew_mean          | 35.4         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 140          |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0009865799 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.826        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 159          |
# |    n_updates            | 556          |
# |    policy_gradient_loss | 0.000409     |
# |    value_loss           | 398          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 618         |
# |    ep_rew_mean          | 35.7        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 141         |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 144384      |
# | train/                  |             |
# |    approx_kl            | 0.008739643 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00613    |
# |    value_loss           | 37.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 624          |
# |    ep_rew_mean          | 38.1         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 142          |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 145408       |
# | train/                  |              |
# |    approx_kl            | 0.0065800278 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.8          |
# |    n_updates            | 564          |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 28.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 624         |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 143         |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 146432      |
# | train/                  |             |
# |    approx_kl            | 0.017365888 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36        |
# |    n_updates            | 568         |
# |    policy_gradient_loss | -0.00197    |
# |    value_loss           | 30.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 624          |
# |    ep_rew_mean          | 39.5         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 144          |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0064198896 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.9         |
# |    n_updates            | 572          |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 26.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 624          |
# |    ep_rew_mean          | 39.6         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 145          |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 148480       |
# | train/                  |              |
# |    approx_kl            | 0.0015903767 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.78         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 199          |
# |    n_updates            | 576          |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 331          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 632          |
# |    ep_rew_mean          | 40.6         |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 146          |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0020752845 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.862        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97.8         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 221          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 639          |
# |    ep_rew_mean          | 41.8         |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 147          |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 150528       |
# | train/                  |              |
# |    approx_kl            | 0.0137204975 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.94         |
# |    n_updates            | 584          |
# |    policy_gradient_loss | -0.00455     |
# |    value_loss           | 12.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | 43.1        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 148         |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.009863399 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 588         |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 24.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 654          |
# |    ep_rew_mean          | 44.4         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 149          |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 152576       |
# | train/                  |              |
# |    approx_kl            | 0.0071960934 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.1         |
# |    n_updates            | 592          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 30.9         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 660           |
# |    ep_rew_mean          | 45.3          |
# | time/                   |               |
# |    fps                  | 570           |
# |    iterations           | 150           |
# |    time_elapsed         | 269           |
# |    total_timesteps      | 153600        |
# | train/                  |               |
# |    approx_kl            | 0.00058618735 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.92         |
# |    explained_variance   | 0.821         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 77.3          |
# |    n_updates            | 596           |
# |    policy_gradient_loss | -0.000925     |
# |    value_loss           | 396           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 653          |
# |    ep_rew_mean          | 44           |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 151          |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 154624       |
# | train/                  |              |
# |    approx_kl            | 0.0010879984 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.803        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 176          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 652          |
# |    ep_rew_mean          | 45.2         |
# | time/                   |              |
# |    fps                  | 571          |
# |    iterations           | 152          |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0015233156 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.855       |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 107          |
# |    n_updates            | 604          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 290          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 652          |
# |    ep_rew_mean          | 45.9         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 153          |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 156672       |
# | train/                  |              |
# |    approx_kl            | 0.0023871525 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.875       |
# |    explained_variance   | 0.888        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.8         |
# |    n_updates            | 608          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 133          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 654          |
# |    ep_rew_mean          | 44.9         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 154          |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 157696       |
# | train/                  |              |
# |    approx_kl            | 0.0034371181 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.8         |
# |    n_updates            | 612          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 76.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 655          |
# |    ep_rew_mean          | 45           |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 155          |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 158720       |
# | train/                  |              |
# |    approx_kl            | 0.0024892543 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.91         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.67         |
# |    n_updates            | 616          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 70.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 656         |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 156         |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.005787945 |
# |    clip_fraction        | 0.00879     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 177         |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 280         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 664         |
# |    ep_rew_mean          | 47.2        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 157         |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 160768      |
# | train/                  |             |
# |    approx_kl            | 0.007619661 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.1        |
# |    n_updates            | 624         |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 71          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 671         |
# |    ep_rew_mean          | 48.1        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 158         |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 161792      |
# | train/                  |             |
# |    approx_kl            | 0.002040755 |
# |    clip_fraction        | 0.00659     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.34        |
# |    n_updates            | 628         |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 52.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 671         |
# |    ep_rew_mean          | 48.1        |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 159         |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 162816      |
# | train/                  |             |
# |    approx_kl            | 0.006246431 |
# |    clip_fraction        | 0.0168      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 632         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 58.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 673          |
# |    ep_rew_mean          | 49.8         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 160          |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0072523626 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 120          |
# |    n_updates            | 636          |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 175          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 674         |
# |    ep_rew_mean          | 53.1        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 161         |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 164864      |
# | train/                  |             |
# |    approx_kl            | 0.010992512 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.68        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0055     |
# |    value_loss           | 20          |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 679           |
# |    ep_rew_mean          | 55            |
# | time/                   |               |
# |    fps                  | 570           |
# |    iterations           | 162           |
# |    time_elapsed         | 290           |
# |    total_timesteps      | 165888        |
# | train/                  |               |
# |    approx_kl            | 0.00086695777 |
# |    clip_fraction        | 0.000488      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.913        |
# |    explained_variance   | 0.468         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 190           |
# |    n_updates            | 644           |
# |    policy_gradient_loss | -0.000551     |
# |    value_loss           | 534           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 679         |
# |    ep_rew_mean          | 55.5        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 163         |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 166912      |
# | train/                  |             |
# |    approx_kl            | 0.012965616 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.97        |
# |    n_updates            | 648         |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 20.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 677         |
# |    ep_rew_mean          | 56.9        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 164         |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.004497945 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.1        |
# |    n_updates            | 652         |
# |    policy_gradient_loss | -0.00437    |
# |    value_loss           | 66.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 677          |
# |    ep_rew_mean          | 57.3         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 165          |
# |    time_elapsed         | 295          |
# |    total_timesteps      | 168960       |
# | train/                  |              |
# |    approx_kl            | 0.0039770724 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 101          |
# |    n_updates            | 656          |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 245          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 669         |
# |    ep_rew_mean          | 56.3        |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 166         |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.009640504 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.24        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00218    |
# |    value_loss           | 16.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 669         |
# |    ep_rew_mean          | 57.3        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 167         |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 171008      |
# | train/                  |             |
# |    approx_kl            | 0.002685434 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.7        |
# |    n_updates            | 664         |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 94.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 669          |
# |    ep_rew_mean          | 57           |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 168          |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0030421242 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.848        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34           |
# |    n_updates            | 668          |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 64.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 678          |
# |    ep_rew_mean          | 57.8         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 169          |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 173056       |
# | train/                  |              |
# |    approx_kl            | 0.0062730066 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.723        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89.7         |
# |    n_updates            | 672          |
# |    policy_gradient_loss | -0.00572     |
# |    value_loss           | 314          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 685         |
# |    ep_rew_mean          | 59.5        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 170         |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.003956546 |
# |    clip_fraction        | 0.00342     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.9        |
# |    n_updates            | 676         |
# |    policy_gradient_loss | -0.00274    |
# |    value_loss           | 99          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 685         |
# |    ep_rew_mean          | 60.2        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 171         |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 175104      |
# | train/                  |             |
# |    approx_kl            | 0.008613298 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.992      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.47        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 13.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | 61.7        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 172         |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.004917033 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.5        |
# |    n_updates            | 684         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 119         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 698          |
# |    ep_rew_mean          | 63.4         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 173          |
# |    time_elapsed         | 310          |
# |    total_timesteps      | 177152       |
# | train/                  |              |
# |    approx_kl            | 0.0056086592 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.91         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.3         |
# |    n_updates            | 688          |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 83.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 698         |
# |    ep_rew_mean          | 63.3        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 174         |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.007327109 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 692         |
# |    policy_gradient_loss | -0.000769   |
# |    value_loss           | 42.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 704         |
# |    ep_rew_mean          | 64.5        |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 175         |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 179200      |
# | train/                  |             |
# |    approx_kl            | 0.013727801 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.6        |
# |    n_updates            | 696         |
# |    policy_gradient_loss | -0.00376    |
# |    value_loss           | 46.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 704        |
# |    ep_rew_mean          | 64.9       |
# | time/                   |            |
# |    fps                  | 569        |
# |    iterations           | 176        |
# |    time_elapsed         | 316        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.00630478 |
# |    clip_fraction        | 0.0269     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.2       |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.00233   |
# |    value_loss           | 24         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 704         |
# |    ep_rew_mean          | 64.5        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 177         |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 181248      |
# | train/                  |             |
# |    approx_kl            | 0.008994494 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.49        |
# |    n_updates            | 704         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 36.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 704          |
# |    ep_rew_mean          | 64.4         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 178          |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0036267182 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.08         |
# |    n_updates            | 708          |
# |    policy_gradient_loss | -0.00051     |
# |    value_loss           | 27.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 711          |
# |    ep_rew_mean          | 65.8         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 179          |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 183296       |
# | train/                  |              |
# |    approx_kl            | 0.0072792396 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.752        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91.6         |
# |    n_updates            | 712          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 184          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 711         |
# |    ep_rew_mean          | 65.1        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 180         |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.008432894 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.19        |
# |    n_updates            | 716         |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 15.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 718          |
# |    ep_rew_mean          | 65.9         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 181          |
# |    time_elapsed         | 325          |
# |    total_timesteps      | 185344       |
# | train/                  |              |
# |    approx_kl            | 0.0034151138 |
# |    clip_fraction        | 0.00317      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.3         |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 49.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | 66.2        |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 182         |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.005362685 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.9         |
# |    n_updates            | 724         |
# |    policy_gradient_loss | -0.00466    |
# |    value_loss           | 26.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | 67.1        |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 183         |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 187392      |
# | train/                  |             |
# |    approx_kl            | 0.004716643 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 728         |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 52.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 721         |
# |    ep_rew_mean          | 68.6        |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 184         |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.008322284 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# ...
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 354         |
# |    time_elapsed         | 638         |
# |    total_timesteps      | 362496      |
# | train/                  |             |
# |    approx_kl            | 0.012209563 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95        |
# |    n_updates            | 1412        |
# |    policy_gradient_loss | -0.000226   |
# |    value_loss           | 5.64        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 808          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 355          |
# |    time_elapsed         | 639          |
# |    total_timesteps      | 363520       |
# | train/                  |              |
# |    approx_kl            | 0.0034655663 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.937       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 152          |
# |    n_updates            | 1416         |
# |    policy_gradient_loss | 0.000482     |
# |    value_loss           | 415          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 808         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 356         |
# |    time_elapsed         | 641         |
# |    total_timesteps      | 364544      |
# | train/                  |             |
# |    approx_kl            | 0.008074093 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.09        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 8.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 808         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 357         |
# |    time_elapsed         | 643         |
# |    total_timesteps      | 365568      |
# | train/                  |             |
# |    approx_kl            | 0.007706199 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19        |
# |    n_updates            | 1424        |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 7.23        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 97.7         |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 358          |
# |    time_elapsed         | 645          |
# |    total_timesteps      | 366592       |
# | train/                  |              |
# |    approx_kl            | 0.0039895363 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.915       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.35         |
# |    n_updates            | 1428         |
# |    policy_gradient_loss | 0.000304     |
# |    value_loss           | 11.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 97.5         |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 359          |
# |    time_elapsed         | 647          |
# |    total_timesteps      | 367616       |
# | train/                  |              |
# |    approx_kl            | 6.686215e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.854       |
# |    explained_variance   | 0.681        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 377          |
# |    n_updates            | 1432         |
# |    policy_gradient_loss | 0.00058      |
# |    value_loss           | 744          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 97.1         |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 360          |
# |    time_elapsed         | 649          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0072946283 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88         |
# |    n_updates            | 1436         |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 9.88         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 779         |
# |    ep_rew_mean          | 93.4        |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 361         |
# |    time_elapsed         | 650         |
# |    total_timesteps      | 369664      |
# | train/                  |             |
# |    approx_kl            | 0.004968765 |
# |    clip_fraction        | 0.0286      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.95        |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | 0.000233    |
# |    value_loss           | 12.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 786         |
# |    ep_rew_mean          | 92.6        |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 362         |
# |    time_elapsed         | 652         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.001262963 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.936      |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 1444        |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 502         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 793         |
# |    ep_rew_mean          | 94          |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 363         |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 371712      |
# | train/                  |             |
# |    approx_kl            | 0.007320156 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.35        |
# |    n_updates            | 1448        |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 6.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 793         |
# |    ep_rew_mean          | 93.6        |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 364         |
# |    time_elapsed         | 655         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.008672377 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.71        |
# |    n_updates            | 1452        |
# |    policy_gradient_loss | -0.00745    |
# |    value_loss           | 11.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 93.7         |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 365          |
# |    time_elapsed         | 658          |
# |    total_timesteps      | 373760       |
# | train/                  |              |
# |    approx_kl            | 0.0036024065 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42         |
# |    n_updates            | 1456         |
# |    policy_gradient_loss | -0.00125     |
# |    value_loss           | 15.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 793           |
# |    ep_rew_mean          | 93.5          |
# | time/                   |               |
# |    fps                  | 567           |
# |    iterations           | 366           |
# |    time_elapsed         | 659           |
# |    total_timesteps      | 374784        |
# | train/                  |               |
# |    approx_kl            | 0.00054862833 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.95         |
# |    explained_variance   | 0.942         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 30.9          |
# |    n_updates            | 1460          |
# |    policy_gradient_loss | 0.000189      |
# |    value_loss           | 135           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 93.6         |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 367          |
# |    time_elapsed         | 661          |
# |    total_timesteps      | 375808       |
# | train/                  |              |
# |    approx_kl            | 0.0044474956 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.67         |
# |    n_updates            | 1464         |
# |    policy_gradient_loss | -0.000514    |
# |    value_loss           | 16.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 797          |
# |    ep_rew_mean          | 92.6         |
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 368          |
# |    time_elapsed         | 663          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0026418294 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.2         |
# |    n_updates            | 1468         |
# |    policy_gradient_loss | -0.000449    |
# |    value_loss           | 104          |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d04635139d89> in <cell line: 2>()
#       1 model_name = "ppo-LunarLander-v2"
# ----> 2 model.learn(total_timesteps=1000000)
#       3 # Save the model
#       4 model_name = "ppo-LunarLander-v2"
#       5 model.save(model_name)
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306         progress_bar: bool = False,
#     307     ) -> SelfPPO:
# --> 308         return super().learn(
#     309             total_timesteps=total_timesteps,
#     310             callback=callback,
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     279                 self.logger.dump(step=self.num_timesteps)
#     280
# --> 281             self.train()
#     282
#     283         callback.on_training_end()
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/ppo/ppo.py in train(self)
#     270                 # Optimization step
#     271                 self.policy.optimizer.zero_grad()
# --> 272                 loss.backward()
#     273                 # Clip grad norm
#     274                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     579                 inputs=inputs,
#     580             )
# --> 581         torch.autograd.backward(
#     582             self, gradient, retain_graph, create_graph, inputs=inputs
#     583         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     823         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824     try:
# --> 825         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826             t_outputs, *args, **kwargs
#     827         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# @title
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=82.10 +/- 108.26226020421092
