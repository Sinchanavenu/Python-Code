# %%
import nltk

from nltk.stem import PorterStemmer

porter = PorterStemmer()

# %%
porter.stem("walking")
# Out:
# 'walk'

# %%
porter.stem("walked")
# Out:
# 'walk'

# %%
porter.stem("walks")
# Out:
# 'walk'

# %%
porter.stem("ran")
# Out:
# 'ran'

# %%
porter.stem("running")
# Out:
# 'run'

# %%
porter.stem("bosses")
# Out:
# 'boss'

# %%
porter.stem("replacement")
# Out:
# 'replac'

# %%
sentence = "Lemmatization is more sophisticated than stemming".split()

for token in sentence:
  print(porter.stem(token), end=" ")
# Out:
# lemmat is more sophist than stem

# %%
porter.stem("unnecessary")
# Out:
# 'unnecessari'

# %%
porter.stem("berry")
# Out:
# 'berri'

# %%
from nltk.stem import WordNetLemmatizer
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet

lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("walking")
# Out:
# 'walking'

# %%
lemmatizer.lemmatize("walking", pos=wordnet.VERB)
# Out:
# 'walk'

# %%
lemmatizer.lemmatize("going")
# Out:
# 'going'

# %%
lemmatizer.lemmatize("going", pos=wordnet.VERB)
# Out:
# 'go'

# %%
lemmatizer.lemmatize("ran", pos=wordnet.VERB)
# Out:
# 'run'

# %%
porter.stem("mice")
# Out:
# 'mice'

# %%
porter.stem("was")
# Out:
# 'wa'

# %%
lemmatizer.lemmatize("was", pos=wordnet.VERB)
# Out:
# 'be'

# %%
porter.stem("is")
# Out:
# 'is'

# %%
lemmatizer.lemmatize("is", pos=wordnet.VERB)
# Out:
# 'be'

# %%
porter.stem("better")
# Out:
# 'better'

# %%
lemmatizer.lemmatize("better", pos=wordnet.ADJ)
# Out:
# 'good'

# %%
def get_wordnet_pos(treebank_tag):
  if treebank_tag.startswith('J'):
    return wordnet.ADJ
  elif treebank_tag.startswith('V'):
    return wordnet.VERB
  elif treebank_tag.startswith('N'):
    return wordnet.NOUN
  elif treebank_tag.startswith('R'):
    return wordnet.ADV
  else:
    return wordnet.NOUN

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
sentence = "Donald Trump has a devoted following".split()

# %%
def simple_lemmatizer(word):
    # A small dictionary for lemmatization
    lemmas = {
        "better": "good",
        "best": "good",
        "running": "run",
        "ran": "run",
        "jumps": "jump",
        "flies": "fly",
        "studies": "study",
    }
    return lemmas.get(word, word)

# Example words for lemmatization
words = ["better", "best", "running", "ran", "jumps", "flies", "studies"]

print("\n=== Simple Lemmatization Examples ===")
for word in words:
    print(f"{word} -> {simple_lemmatizer(word)}")
# Out:
# === Simple Lemmatization Examples ===
# better -> good
# best -> good
# running -> run
# ran -> run
# jumps -> jump
# flies -> fly
# studies -> study

# %%
words_and_tags = nltk.pos_tag(sentence)
words_and_tags
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-30-c2869af487f9> in <cell line: 1>()
# ----> 1 words_and_tags = nltk.pos_tag(sentence)
#       2 words_and_tags
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#     170
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     108         tagger = PerceptronTagger(lang=lang)
#     109     else:
# --> 110         tagger = PerceptronTagger()
#     111     return tagger
#     112
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/perceptron.py in __init__(self, load, lang)
#     181         self.classes = set()
#     182         if load:
# ...

# %%
for word, tag in words_and_tags:
  lemma = lemmatizer.lemmatize(word, pos=get_wordnet_pos(tag))
  print(lemma, end=" ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-969aa8d3b01e> in <cell line: 1>()
# ----> 1 for word, tag in words_and_tags:
#       2   lemma = lemmatizer.lemmatize(word, pos=get_wordnet_pos(tag))
#       3   print(lemma, end=" ")
#
# NameError: name 'words_and_tags' is not defined
