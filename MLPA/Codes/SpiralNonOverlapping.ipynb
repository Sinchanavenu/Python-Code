# %% [markdown]
# ---
# Linear Kernel
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# Generate a spiral non-overlapping dataset
def generate_spiral_data_nonoverlapping(n_samples=1000):
    theta = np.linspace(0, 4 * np.pi, n_samples)
    r = theta + 2
    x = r * np.sin(theta)
    y = r * np.cos(theta)
    labels = np.array([0 if i < n_samples // 2 else 1 for i in range(n_samples)])
    return np.column_stack((x, y)), labels

X, y = generate_spiral_data_nonoverlapping(n_samples=100)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Function to plot decision boundaries
def plot_decision_boundaries(X, y, model, ax):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
    ax.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.coolwarm)

# Try different C and gamma values
C_values = [0.1, 1, 10]
gamma_values = [0.1, 1, 'scale']

# Create subplots for all combinations of C and gamma
fig, axes = plt.subplots(len(C_values), len(gamma_values), figsize=(12, 12))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Linear Kernel
for i, C in enumerate(C_values):
    for j, gamma in enumerate(gamma_values):
        model = SVC(kernel='linear', C=C, gamma=gamma)
        model.fit(X_train, y_train)
        ax = axes[i, j]
        plot_decision_boundaries(X, y, model, ax)
        ax.set_title(f"Linear Kernel\nC={C}, gamma={gamma}")

plt.show()

# %% [markdown]
# ---
# Sigmoid Kernel
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Generate a spiral non-overlapping dataset
def generate_spiral_data_nonoverlapping(n_samples=1000):
    theta = np.linspace(0, 4 * np.pi, n_samples)
    r = theta + 2
    x = r * np.sin(theta)
    y = r * np.cos(theta)
    labels = np.array([0 if i < n_samples // 2 else 1 for i in range(n_samples)])
    return np.column_stack((x, y)), labels

X, y = generate_spiral_data_nonoverlapping(n_samples=1000)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Function to plot decision boundaries
def plot_decision_boundaries(X, y, model, ax):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
    ax.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.coolwarm)

# Try different C and gamma values
C_values = [0.1, 1, 10]
gamma_values = [0.1, 1, 'scale']

# Create subplots for all combinations of C and gamma
fig, axes = plt.subplots(len(C_values), len(gamma_values), figsize=(12, 12))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Sigmoid Kernel
for i, C in enumerate(C_values):
    for j, gamma in enumerate(gamma_values):
        model = SVC(kernel='sigmoid', C=C, gamma=gamma)
        model.fit(X_train, y_train)
        ax = axes[i, j]
        plot_decision_boundaries(X, y, model, ax)
        ax.set_title(f"Sigmoid Kernel\nC={C}, gamma={gamma}")

plt.show()

# %% [markdown]
# ---
# Polynomial Kernel
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Generate a spiral non-overlapping dataset
def generate_spiral_data_nonoverlapping(n_samples=1000):
    theta = np.linspace(0, 4 * np.pi, n_samples)
    r = theta + 2
    x = r * np.sin(theta)
    y = r * np.cos(theta)
    labels = np.array([0 if i < n_samples // 2 else 1 for i in range(n_samples)])
    return np.column_stack((x, y)), labels

X, y = generate_spiral_data_nonoverlapping(n_samples=1000)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Function to plot decision boundaries
def plot_decision_boundaries(X, y, model, ax):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
    ax.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.coolwarm)

# Try different C and gamma values
C_values = [0.1, 1, 10]
gamma_values = [0.1, 1, 'scale']

# Create subplots for all combinations of C and gamma
fig, axes = plt.subplots(len(C_values), len(gamma_values), figsize=(12, 12))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Polynomial Kernel
for i, C in enumerate(C_values):
    for j, gamma in enumerate(gamma_values):
        model = SVC(kernel='poly', C=C, gamma=gamma)
        model.fit(X_train, y_train)
        ax = axes[i, j]
        plot_decision_boundaries(X, y, model, ax)
        ax.set_title(f"Polynomial Kernel\nC={C}, gamma={gamma}")

plt.show()

# %% [markdown]
# ---
# RBF Kernel
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Generate a spiral non-overlapping dataset
def generate_spiral_data_nonoverlapping(n_samples=1000):
    theta = np.linspace(0, 4 * np.pi, n_samples)
    r = theta + 2
    x = r * np.sin(theta)
    y = r * np.cos(theta)
    labels = np.array([0 if i < n_samples // 2 else 1 for i in range(n_samples)])
    return np.column_stack((x, y)), labels

X, y = generate_spiral_data_nonoverlapping(n_samples=1000)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Function to plot decision boundaries
def plot_decision_boundaries(X, y, model, ax):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
    ax.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.coolwarm)

# Try different C and gamma values
C_values = [0.1, 1, 10]
gamma_values = [0.1, 1, 'scale']

# Create subplots for all combinations of C and gamma
fig, axes = plt.subplots(len(C_values), len(gamma_values), figsize=(12, 12))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# RBF Kernel
for i, C in enumerate(C_values):
    for j, gamma in enumerate(gamma_values):
        model = SVC(kernel='rbf', C=C, gamma=gamma)
        model.fit(X_train, y_train)
        ax = axes[i, j]
        plot_decision_boundaries(X, y, model, ax)
        ax.set_title(f"RBF Kernel\nC={C}, gamma={gamma}")

plt.show()
